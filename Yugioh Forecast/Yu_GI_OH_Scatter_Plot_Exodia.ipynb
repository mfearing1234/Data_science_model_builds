# %%
# !pip install matplotlib
# !pip install seaborn
# !pip install pandas
# !pip install numpy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import csv

# %%
#read from dataset
df = pd.read_csv("yugioh_enriched.csv", usecols=['name','card_sets_set_name','card_sets_set_price'])
df.columns
# Out:
# Index(['name', 'card_sets_set_name', 'card_sets_set_price'], dtype='str')

# %%
#Read top 5 rows
df.head(5)
# Out:
#                        name                     card_sets_set_name  \
# 0            Tornado Dragon  Battles of Legend: Relentless Revenge
# 1            Tornado Dragon                        Duel Devastator
# 2            Tornado Dragon      Legendary Duelists: Synchro Storm
# 3            Tornado Dragon                         Maximum Crisis
# 4  Exodia the Forbidden One                       Dark Beginning 1
#
#    card_sets_set_price
# 0                 4.65
# 1                 1.58
# 2                 0.96
# 3                 4.49
# 4                40.10

# %%
#Search row for specific card
df= df[df['name']=='Exodia the Forbidden One'].reset_index()

#Check top rows
df.head(15)
# Out:
#     index                      name  \
# 0       4  Exodia the Forbidden One
# 1       5  Exodia the Forbidden One
# 2       6  Exodia the Forbidden One
# 3       7  Exodia the Forbidden One
# 4       8  Exodia the Forbidden One
# 5       9  Exodia the Forbidden One
# 6      10  Exodia the Forbidden One
# 7      11  Exodia the Forbidden One
# 8      12  Exodia the Forbidden One
# 9      13  Exodia the Forbidden One
# 10     14  Exodia the Forbidden One
# 11     15  Exodia the Forbidden One
# 12     16  Exodia the Forbidden One
# 13     17  Exodia the Forbidden One
# 14     18  Exodia the Forbidden One
#
#                                 card_sets_set_name  card_sets_set_price
# 0                                 Dark Beginning 1                40.10
# 1                                     Dark Legends               124.91
# 2             Duelist League 2 participation cards                35.39
# 3                 Legend of Blue Eyes White Dragon                33.07
# 4                 Legend of Blue Eyes White Dragon               220.62
# 5                 Legend of Blue Eyes White Dragon                88.16
# 6   Legendary Collection 3: Yugi's World Mega Pack                30.52
# 7                               Legendary Decks II                 4.80
# 8                       Master Collection Volume 1                14.46
# 9                          Maximum Gold: El Dorado                 0.00
# 10                         Maximum Gold: El Dorado                 3.40
# 11               Premium Gold: Return of the Bling                 9.51
# 12                                      Retro Pack                 0.00
# 13                        The Lost Art Promotion D                42.75
# 14   Yu-Gi-Oh! Dark Duel Stories promotional cards               775.93

# %%
#Generate Scatter Plot for Card Prices

fig, ax = plt.subplots(1,1, figsize=(40,20))

x= df['card_sets_set_name']
y= df['card_sets_set_price']

sorted_df = df.sort_values(by='card_sets_set_price', ascending=False)
ax.scatter(sorted_df['card_sets_set_name'], sorted_df['card_sets_set_price'])
plt.title("Exodia Price: Across Sets")
plt.legend(["Price"])
plt.xlabel("Card Set")
plt.ylabel("Card Price")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 8
#       5 x= df['card_sets_set_name']
#       6 y= df['card_sets_set_price']
# ----> 8 plt.scatter(x,y).sort_values(by='card_sets_set_price', ascending=False)
#       9 plt.title("Exodia Price: Across Sets")
#      10 plt.legend(["Price"])
#
# AttributeError: 'PathCollection' object has no attribute 'sort_values'
