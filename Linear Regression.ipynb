# %%
# !pip list --outdated
# Out:
# Package                       Version   Latest      Type
# ----------------------------- --------- ----------- -----
# alabaster                     0.7.12    0.7.13      wheel
# asn1crypto                    1.0.1     1.5.1       wheel
# astroid                       2.3.1     2.15.0      wheel
# astropy                       3.2.1     4.3.1       wheel
# atomicwrites                  1.3.0     1.4.1       sdist
# attrs                         19.2.0    22.2.0      wheel
# Babel                         2.7.0     2.12.1      wheel
# backcall                      0.1.0     0.2.0       wheel
# backports.functools-lru-cache 1.5       1.6.4       wheel
# beautifulsoup4                4.8.2     4.11.2      wheel
# bitarray                      1.0.1     2.7.3       wheel
# bleach                        3.1.0     6.0.0       wheel
# bokeh                         1.3.4     2.4.3       wheel
# Bottleneck                    1.2.1     1.3.7       wheel
# ...

# %%
# !pip upgrade
