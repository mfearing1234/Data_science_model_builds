# %%
import numpy as np

# %%
x = np.array([25,2,5]) # type argument is optional, e.g.: dtype = np.float116

# %%
len(x)
# Out:
# 3

# %%
x.shape
# Out:
# (3,)

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x[0] #zero indexed
# Out:
# 25

# %%
type(x[0])
# Out:
# numpy.int64

# %% [markdown]
# ## Vector Transposition

# %%
x_t = x.T
x_t
# Out:
# array([25,  2,  5])

# %%
x_t.shape
# Out:
# (3,)

# %%
# it does use nested 'matrix-style' brackets:
y = np.array([[25,2,5]])
y
# Out:
# array([[25,  2,  5]])

# %%
y.shape
# Out:
# (1, 3)

# %%
# it can transpose a matrix with a dimension of length 1, which is mathematically equivalent
y_t = y.T
y_t
# Out:
# array([[25],
#        [ 2],
#        [ 5]])

# %%
#Column vector can be transposed back to original row vector:
y_t.T
y_t
# Out:
# array([[25],
#        [ 2],
#        [ 5]])

# %%
y_t.shape
# Out:
# (3, 1)

# %% [markdown]
# ## Zero Vectors

# %%
# have no effect if added to another vector
z = np.zeros(3)
z
# Out:
# array([0., 0., 0.])

# %% [markdown]
# ## Vectors in PyTorch and TensorFlow

# %%
x_pt = torch.tensor([25,2,5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 x_pt = torch.tensor([25,2,5])
#
# NameError: name 'torch' is not defined

# %%
x_tf = tf.Variable([25,2,5])

# %% [markdown]
# ## L^2 Norm

# %%
x
# Out:
# array([25,  2,  5])

# %%
(25**2 + 2**2 + 5**2)**(1/2)
# Out:
# 25.573423705088842

# %%
np.linalg.norm(x)
# Out:
# 25.573423705088842

# %% [markdown]
# So, if units in this 3-dimensional vector space are meters, then the vector x has a length of 25.6m

# %% [markdown]
# ## Squared L^2 Norm

# %%
x
# Out:
# array([25,  2,  5])

# %%
(25*2+2**2+5**2)
# Out:
# 79

# %%
np.dot(x,x)
# Out:
# 654

# %% [markdown]
# ## Max Norm

# %%
x
# Out:
# array([25,  2,  5])

# %%
np.max([np.abs(25), np.abs(2), np.abs(5)])
# Out:
# 25

# %% [markdown]
# ## Orthogonal Vectors
