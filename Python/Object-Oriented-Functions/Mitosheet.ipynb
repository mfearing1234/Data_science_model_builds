# %%
import mitosheet
mitosheet.sheet(analysis_to_replay='')
# Out:
# ...
#   Obtaining dependency information for mitosheet from https://files.pythonhosted.org/packages/38/8f/47d78b391d8b3302ccb970c3726bf2b96502be138895ad53bca58eded2b2/mitosheet-0.1.560-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for analytics-python from https://files.pythonhosted.org/packages/67/84/d41972eeddd7299bd2e2246a9be78abba46f2d255c0c435c64748cd99088/analytics_python-1.4.post1-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for xlsxwriter<=3.1.3,>=0.6.9 from https://files.pythonhosted.org/packages/6a/8c/5982a902521519d3f671bd24bce63eda474d7f16502c78ac2bb5ab889aa0/XlsxWriter-3.1.3-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for monotonic>=1.5 from https://files.pythonhosted.org/packages/9a/67/7e8406a29b6c45be7af7740456f7f37025f0506ae2e05fb9009a53946860/monotonic-1.6-py2.py3-none-any.whl.metadata
# ...
