# %%
x = 'I am cold'

def count_spaces(sentence):
    spaces = 0
    for i in sentence:
        if i == ' ':
            spaces = spaces + 1
    print(spaces)


count_spaces(x)
# Out:
# 2

# %%
x = 'I am cold'

def count_spaces(sentence):
    spaces = 0
    for i in sentence:
        if i == ' ':
            spaces = spaces + 1
    print(spaces)


count_spaces(x)
# Out:
# 2

# %%
x = 'I am cold'
class SpaceCounter:
    def count_spaces(self, sentence):
        return sentence.count(' ')


s = SpaceCounter()
print(s.count_spaces(x))
# Out:
# 2

# %%
sentence = 'I      go  to mall'

class space_counter:
    """Blueprint for counting spaces"""
    def count_spaces(self, x):
        spaces = 0
        for i in x:
            if i == ' ' and x[-1] != ' ':
                spaces = spaces + 1
        return spaces

s=space_counter
s.count_spaces(s,sentence)

# %%
list = ['a','b','c','d']

for i, letter in enumerate(list):
    print(letter)
# Out:
# a
# b
# c
# d

# %%
import pandas as pd
x = [(1,'a'),(2,'B')]

df = pd.DataFrame(x)

df.iloc[0,1]
# Out:
# 'a'

# %%
from tkinter import *
class MyFrame(Frame):
  def __init__(self):
     Frame.__init__(self)
		# Now create a MyFrame object and call on mainloop
frame02 = MyFrame()
frame02.mainloop()

# %%
sentences = 'I go    swi &mmi ng % '
class counter():
    def __init__(self):
        self.spaces = 0
        self.previous = False
    def total_spaces (self, sentence):
        for i in sentence:
            if i == ' ':
                self.spaces += 1
        return print(f"There are {self.spaces} total spaces between the letters in the sentence.")
    def unique_space (self,sentence):
        for i in sentence:
            if i == ' ' and self.previous == False:
                self.spaces += 1
                self.previous = True
            elif i != ' ':
                self.previous = False

        return print(f"There are {self.spaces} unique spaces between the letters in the sentence.")
    def unique_special_characters (self, sentence):
        count = self.spaces
        for i in sentence:
            if i in ['%','&','#','*']:
                count += 1
                self.previous = True
            elif i not in ['%','&','#','*']:
                self.previous = False
        return(print(f"There are {count} unique special characters between the letters in the sentence."))
sc= counter()
sc.unique_space(sentences)
sc.total_spaces(sentences)
sc.unique_special_characters(sentences)
# Out:
# There are 2 unique special characters between the letters in the sentence.

# %%
sentences = 'A B C D & % E F'

class special_characters():
    def __init__(self):
        self.character_count = 0
        self.previous = False
    def unique_special_characters (self, sentence):
        count = spaces
        for i in sentence:
            if i in ['%','&','#','*']:
                spaces += 1
                self.previous = True
            elif i not in ['%','&','#','*']:
                self.previous = False
        return(count)

sc = special_characters()
sc.unique_special_characters(sentences)
# Out:
# 2
